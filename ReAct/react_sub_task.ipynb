# %%
import re
import os
import io
import sys
import requests
import pandas as pd
from tqdm import tqdm
from openai import OpenAI
from dotenv import load_dotenv
from colorama import Fore, Style, init
from googleapiclient.discovery import build

load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
GOOGLE_CSE_ID = os.getenv('GOOGLE_CSE_ID')
google_fact_check_api_key = os.getenv('google_fact_check_api_key')
API_KEY = os.getenv('OPENAI_API_KEY')

client = OpenAI(api_key=API_KEY)

# Initialize colorama
init()

class FactChecker:
    def __init__(self):
        self.messages = []
        self.tools_used = False
        self.available_functions = {
            "call_google": self.call_google,
            "call_google_fact_check": self.call_google_fact_check
        }
    
    def call_google(self, query, **kwargs):
        try:
            service = build(serviceName="customsearch",
                          version="v1",
                          developerKey=GOOGLE_API_KEY,
                          static_discovery=False)
            res = service.cse().list(q=query, cx=GOOGLE_CSE_ID, **kwargs).execute()
            res_items = res["items"]
            res_snippets = [r['snippet'] for r in res_items]
            self.tools_used = True
            return str(res_snippets)
        except Exception as e:
            print(Fore.RED + f"Error: {str(e)}")
            print(Style.RESET_ALL)
            return f"Error in Google search: {str(e)}"

    def call_google_fact_check(self, query):
        try:
            url = f"https://factchecktools.googleapis.com/v1alpha1/claims:search?key={google_fact_check_api_key}&query={query}"
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()
                self.tools_used = True
                if not data.get("claims"):
                    self.tools_used = False  # if no claims are found, set tools_used to False
                    return "No claims found for this query."
                else:
                    result = []
                    for claim in data.get("claims", []):
                        text = claim.get("text", "N/A")
                        rating = claim['claimReview'][0].get('textualRating', 'N/A') if claim.get('claimReview') else 'No rating available'
                        review_url = claim['claimReview'][0].get('url', 'N/A') if claim.get('claimReview') else 'No review URL available'
                        result.append(f"Claim: {text}\nRating: {rating}\nReview URL: {review_url}")
                    return "\n".join(result)
            else:
                return f"Error: {response.status_code} - {response.text}"
        except Exception as e:
            print(Fore.RED + f"Error: {str(e)}")
            print(Style.RESET_ALL)
            return f"Error in fact check: {str(e)}"
        
    def extract_sub_questions(self, article):
        """抽取子問題的prompt"""
        prompt = f"""
        Please analyze the following article and break it down into 2-3 key factual claims 
        that need to be verified. Format them as numbered questions:
        
        Article: {article}
        
        Please list the sub-questions in this format:
        1. [First question]
        2. [Second question]
        3. [Third question]
        """
        
        messages = [
            {"role": "system", "content": "You are an expert at breaking down articles into key verifiable claims."},
            {"role": "user", "content": prompt}
        ]
        
        response = client.chat.completions.create(
            model='gpt-3.5-turbo',
            messages=messages
        )
        
        return response.choices[0].message.content
    
    def verify_sub_question(self, sub_question, article):
        """驗證單個子問題"""
        self.messages = []
        self.tools_used = False
    
        sys_prompt = """
        You are a fact-checking specialist. Verify the specific claim by:
        1. Thinking about what you already know and what you need to verify
        2. Choose the most appropriate tool to find the information:
            - call_google: For general information and recent events
            - call_google_fact_check: For verifying specific controversial claims
        3. Analyzing the search results
        4. Providing a conclusion
    
        You must use this format:
        Thought: [Your reasoning]
        Action: [call_google or call_google_fact_check]: [search query]
    
        After receiving an observation:
        Thought: [Analysis combining your knowledge and the new information]
        Action: [Another search if needed]
        or
        Answer: [Your final conclusion]
    
        Available actions:
        call_google: [search term]
        call_google_fact_check: [seldom key word about the claim(e.g. if you are verifying "COVID-19 is a hoax", you can use "COVID-19")]

        """
        user_prompt = f"Sub-question: {sub_question}\nArticle context: {article}\n\nPlease verify this claim using both your knowledge and external sources when needed."
    
        self.messages = [
            {"role": "system", "content": sys_prompt},
            {"role": "user", "content": user_prompt}
        ]
    
        return self._run_verification_loop()

    def _run_verification_loop(self):
        action_re = re.compile('^Action: (\w+): (.*)$')
        answer_re = re.compile("Answer: ")
        count = 0
    
        while True:
            response = client.chat.completions.create(
                model='gpt-3.5-turbo',
                messages=self.messages
            )
        
            response_msg = response.choices[0].message.content
            self.messages.append({"role": "assistant", "content": response_msg})
        
            # check if tools have been used
            if answer_re.search(response_msg) and self.tools_used:
                print(Fore.YELLOW + response_msg)
                print(Style.RESET_ALL)
                return self._extract_answer(response_msg)
            elif answer_re.search(response_msg):
                print(Fore.YELLOW + "Answer found but tools have not been used. Searching tools now.")
                print(Style.RESET_ALL)

            print(Fore.GREEN + response_msg)
            print(Style.RESET_ALL)
        
            actions = [action_re.match(a) for a in response_msg.split("\n") if action_re.match(a)]
            if actions:
                action, action_input = actions[0].groups()
                try:
                    print(Fore.CYAN + f" -- running {action} {action_input}")
                    print(Style.RESET_ALL)
                
                    observation = self.available_functions[action](action_input)
                    self.tools_used = True
                
                    if "No claims found" in observation:
                        self.tools_used = False

                    print(Fore.BLUE + f"Observation: {observation}")
                    print(Style.RESET_ALL)
                    self.messages.append({"role": "user", "content": "Observation: " + observation})
            
                except Exception as e:
                    print(Fore.RED + f"Error: {e}")
                    print(Style.RESET_ALL)
                    continue
        
            # no action detected
            else:
                count += 1
                if count == 3:
                    print(Fore.RED + "No action is detected. The answer is Unknown.")
                    return None
                print(Fore.RED + "No action is detected. Continue...")
                self.tools_used = False
                continue
    
    def _extract_answer(self, response_msg):
        """從回應中提取答案"""
        lines = response_msg.split('\n')
        for line in lines:
            if line.startswith('Answer:'):
                try:
                    answer = int(line.replace('Answer:', '').strip())
                    return answer
                except ValueError:
                    continue
        return None
    

    def _execute_action(self, action, action_input):
        """執行搜尋動作"""
        if action in self.available_functions:
            print(Fore.CYAN + f" -- running {action} {action_input}")
            print(Style.RESET_ALL)
            result = self.available_functions[action](action_input)
            print(Fore.BLUE + f"Observation: {result}")
            print(Style.RESET_ALL)
            return result
        else:
            print(Fore.RED + f"Unknown action: {action}")
            print(Style.RESET_ALL)
            return f"Unknown action: {action}"
                
    def combine_results(self, results, article):
        """綜合所有子問題的結果"""
        prompt = f"""
        Based on the verification results of all sub-questions:
        {results}
    
        Original article:
        {article}
    
        Please provide a final conclusion about whether the article contains any misleading information.
        First provide your detailed reasoning, then end with either:
        Final Answer: 1 (if misleading)
        Final Answer: 0 (if accurate)
        """
    
        messages = [
            {"role": "system", "content": "You are a fact-checking expert providing final conclusions based on detailed analysis of multiple claims."},
            {"role": "user", "content": prompt}
        ]
    
        response = client.chat.completions.create(
            model='gpt-3.5-turbo',
            messages=messages
        )
    
        return response.choices[0].message.content

    def verify_article(self, article):
        """主要驗證流程"""
        print(Fore.CYAN + "Extracting sub-questions..." + Style.RESET_ALL)
        sub_questions = self.extract_sub_questions(article)
        print(Fore.YELLOW + "Sub-questions extracted:\n" + sub_questions + Style.RESET_ALL)
        
        results = []
        for q in sub_questions.split("\n"):
            if q.strip() and q[0].isdigit():
                print(Fore.CYAN + f"\nVerifying: {q}" + Style.RESET_ALL)
                result = self.verify_sub_question(q, article)
                results.append(f"Question: {q}\nResult: {result}")
        
        print(Fore.CYAN + "\nCombining results..." + Style.RESET_ALL)
        final_conclusion = self.combine_results(results, article)
        print(Fore.YELLOW + "\nFinal conclusion:\n" + final_conclusion + Style.RESET_ALL)
        
        return final_conclusion
    
    def _clean_ansi_codes(self, text):
        """移除文字中的 ANSI 顏色代碼"""
        ansi_escape = re.compile(r'\x1B(?:[@-Z\\-_]|\[[0-?]*[ -/]*[@-~])')
        return ansi_escape.sub('', text)
    
    def process_article_batch(self, input_file, output_file, num_files=None):
        """處理整個Excel文件中的文章"""
        log_file = "fact_checking_process.log"
        
        try:
            with open(log_file, 'w', encoding='utf-8') as f:
                try:
                    df = pd.read_csv(input_file, encoding='utf-8-sig')
                except UnicodeDecodeError:
                    df = pd.read_csv(input_file, encoding='latin1')
        
                if num_files is not None:
                    df_to_process = df.head(num_files)
                else:
                    df_to_process = df
            
                df['fact_check_response'] = ''
                df['Simplified Answer'] = ''

                df.to_csv(output_file, index=False, encoding='utf-8-sig')
                print("開始處理文章...")
        
                for idx, row in tqdm(df_to_process.iterrows(), total=len(df_to_process), desc="Processing articles"):
                    
                    article = row['synthetic_misinformation']    # LLMFake 
                    # article = row['text']   # mmsoc_gossipcop_text_labels-100 

                    # 捕獲所有輸出到一個字符串中
                    output_capture = io.StringIO()
                    original_stdout = sys.stdout
                    sys.stdout = output_capture

                    try:
                        result = self.verify_article(article)
                    finally:
                        sys.stdout = original_stdout

                    detailed_output = output_capture.getvalue()
                    cleaned_output = self._clean_ansi_codes(detailed_output)    
                    simplified_answer = self._extract_simplified_answer(result)

                    f.write(detailed_output)
                    f.flush()

                    current_df = pd.read_csv(output_file, encoding='utf-8-sig')

                    current_df.at[idx, 'fact_check_response'] = cleaned_output
                    current_df.at[idx, 'Simplified Answer'] = simplified_answer
            
                    current_df.to_csv(output_file, index=False, encoding='utf-8-sig')

                print(f"\nAll articles processed. Results saved to {output_file}", file=original_stdout)
        
        except Exception as e:
            print(f"Error processing batch: {str(e)}", file=original_stdout)
            raise e
  
    def _extract_simplified_answer(self, response):
        """從回應中提取簡化的答案 (1 或 0)"""
        try:
            match = re.search(r"Final Answer:\s*(\d)", response)
            if match:
                return int(match.group(1))
        
            digits = re.findall(r'[01]', response)
            if digits:
                return int(digits[-1])
            else:
                return "Unknown"
        except Exception:
            return "Error"

# %% [markdown]
# ## 分析整個檔案

# %%
def main():
    input_file = "LLMFake_politifact-100.csv"  # if LLMFake file，revise above to synthetic_misinformation
    output_file = "react_child_task_LLMFake_politifact-100.csv"
    num_files_to_process = 100
    
    checker = FactChecker()
    
    try:
        checker.process_article_batch(input_file, output_file, num_files=num_files_to_process)
        
    except Exception as e:
        print(Fore.RED + f"Error in main execution: {str(e)}" + Style.RESET_ALL)
        sys.exit(1)

if __name__ == "__main__":
    main()
# Out:
# 開始處理文章...
# Processing articles:   0%|          | 0/100 [00:00<?, ?it/s]/tmp/ipykernel_2079511/2723470168.py:340: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Extracting sub-questions...
# Sub-questions extracted:
# 1. Is Senator Schumer immune to the kind of sexual accusations that many congressmen in Washington have been accused of recently?
#
# 2. Has the author made hasty posts in the past that might have been questionable, but clarifies that they were not made out of ill will?
#
# Verifying: 1. Is Senator Schumer immune to the kind of sexual accusations that many congressmen in Washington have been accused of recently?
# Thought: This claim suggests that Senator Schumer may be immune to the kind of sexual accusations that other congressmen in Washington have faced recently. To verify this claim, I will need to look up any specific accusations or controversies related to Senator Schumer and compare them to the claims made in the article. I will also check for any recent news about Schumer and sexual misconduct allegations.
# Action: call_google_fact_check: Senator Schumer sexual misconduct allegations
#
#  -- running call_google_fact_check Senator Schumer sexual misconduct allegations
#
# Observation: No claims found for this query.
#
# Answer found but tools have not been used. Searching tools now.
#
# Thought: Since no specific information or claims were found regarding Senator Schumer and sexual misconduct allegations, I will rely on my existing knowledge about Senator Schumer and his previous record. Senator Schumer does not have a history of being accused of sexual misconduct, and there have been no recent allegations reported against him.
# Answer: Based on the lack of evidence and Senator Schumer's clean record, there is no reason to believe that he is immune to the kind of sexual accusations that some congressmen in Washington have faced.
#
# No action is detected. Continue...
# Answer found but tools have not been used. Searching tools now.
#
# Answer: Based on the lack of evidence and Senator Schumer's clean record, there is no reason to believe that he is immune to the kind of sexual accusations that some congressmen in Washington have faced.
#
# No action is detected. Continue...
# Answer found but tools have not been used. Searching tools now.
#
# Answer: Based on the lack of evidence and Senator Schumer's clean record, there is no reason to believe that he is immune to the kind of sexual accusations that some congressmen in Washington have faced.
#
# No action is detected. The answer is Unknown.
#
# Verifying: 2. Has the author made hasty posts in the past that might have been questionable, but clarifies that they were not made out of ill will?
# Thought: This claim refers to the author acknowledging making past hasty posts that may have been questionable, but clarifies that they were not made with ill intent. To verify this, it may be necessary to search for information related to the author's past posts to assess their nature and context.
# Action: call_google: author's name + past controversial posts + clarification of intent
#
#  -- running call_google author's name + past controversial posts + clarification of intent
#
# Observation: ["The purpose, as the name implies, is to introduce the reader to the topic ... List of the author's previous books; Title; Copyright page; Dedication\xa0...", 'Aug 29, 2021 ... 212 votes, 187 comments. https://www.them.us/story/lilly-wachowski-work-in-progress-season-two-showtime - You confirmed last year that The\xa0...', "May 27, 2015 ... The thesis statement captures the author's point of view on a controversial topic, ... The Misses (last name), (last name), and (last name).", 'Nov 19, 2022 ... At his latest interview in NYC, Isayama admits that at the very last moment, he felt pressure to give Eren an ending befitting a good character.', 'Sep 1, 2024 ... Note from Jane: This is a cornerstone post of my site, regularly updated. Whenever you decide to directly quote, excerpt, or reproduce\xa0...', "Mar 24, 2010 ... Whatever the power of a trial, authors need to properly report their intended ... Authors should provide the name of the register and the trial's\xa0...", 'The purpose of this primer is to provide a resource for public officials on the basic tenets of effective communications generally and on working with print,\xa0...', 'I sat with the person who had shown me the demo, a brilliant programmer named Charles Simonyi, and we immediately started brainstorming about all the things we\xa0...', "I've been thinking about that in the context of the second amendment—the right to bear arms—so I went back to read the intent of the founders. I found the\xa0...", 'More than 200 years ago, Alexander Hamilton, James Madison, and John Jay published a series of essays promoting the ratification of the United States\xa0...']
#
# Thought: The search results do not provide relevant information about the author's past controversial posts or clarifications of intent. It seems that the author's name might not be specific enough to produce relevant results in this context.
# Action: call_google: specific author's name + past controversial posts + clarification of intent
#
#  -- running call_google specific author's name + past controversial posts + clarification of intent
#
# Observation: ["... particular field writes the introduction to a book being reissued after its author's death. The purpose, as the name implies, is to introduce the reader to\xa0...", 'Nov 19, 2022 ... At his latest interview in NYC, Isayama admits that at the very last moment, he felt pressure to give Eren an ending befitting a good character.', "May 27, 2015 ... The use of the name or mark of any specific manufacturer, commercial product, commodity, or ... The thesis statement captures the author's point\xa0...", 'Apr 15, 2024 ... For a nice middle-ground argument there was this post which showed a few pages from the old Horus Heresy black books which went over Custodes\xa0...', 'For example, rather than responding directly to an individual posting false information, follow the old adage “focus on the issue, and not the person” with a\xa0...', 'Jan 25, 2019 ... It is important that guideline commissioners, developers and review authors are aware that specific ... clarification of the purpose, designs and\xa0...', 'Technically, the term artificial intelligence refers to a model created to solve a specific problem or provide a particular service. What is powering things\xa0...', "I've been thinking about that in the context of the second amendment—the right to bear arms—so I went back to read the intent of the founders. I found the\xa0...", 'Grade-specific K–12 standards in reading, writing, speaking, listening, and language translate the broad (and, for the earliest grades, seemingly distant) aims\xa0...', 'Mar 24, 2010 ... Thus, in the CONSORT checklist we have dropped the specific request for intention ... Authors should provide the name of the register and\xa0...']
#
# Thought: The search results are still not providing relevant information about the specific author's past controversial posts or clarifications of intent. It's possible that the author's name might not be widely recognized or linked with any notable controversial posts.
# Action: call_google: specific author's name + controversial past posts + clarification of intent
#
#  -- running call_google specific author's name + controversial past posts + clarification of intent
#
# Observation: ["... particular field writes the introduction to a book being reissued after its author's death. The purpose, as the name ... controversial. It's a handy way to\xa0...", "May 27, 2015 ... The use of the name or mark of any specific manufacturer, commercial product, commodity, or ... The thesis statement captures the author's point\xa0...", 'Nov 19, 2022 ... At his latest interview in NYC, Isayama admits that at the very last moment, he felt pressure to give Eren an ending befitting a good character.', 'Jan 25, 2019 ... It is important that guideline commissioners, developers and review authors are aware that specific ... clarification of the purpose, designs and\xa0...', 'Dec 15, 2023 ... Well, I knew this is going to happen, but I wrote this post anyways, because I wanted to get the truth out there, and to try and stop the\xa0...', 'Mar 24, 2010 ... Thus, in the CONSORT checklist we have dropped the specific request for intention ... Authors should provide the name of the register and\xa0...', 'For example, rather than responding directly to an individual posting false information, follow the old adage “focus on the issue, and not the person” with a\xa0...', 'Grade-specific K–12 standards in reading, writing, speaking, listening, and language translate the broad (and, for the earliest grades, seemingly distant) aims\xa0...', 'Feb 27, 2024 ... A thesis statement clearly identifies the topic being discussed, includes the points discussed in the paper, and is written for a specific audience.', "Pose and respond to specific questions to clarify or follow up on information, and make ... Analyze an author's purpose in providing an explanation, describing a\xa0..."]
#
# Thought: Despite multiple searches, the search results are still not providing relevant information about the specific author's past controversial posts or clarifications of intent. It appears that there isn't readily available information linking the author to the claimed hasty posts or clarifications.
# Action: Based on the lack of relevant search results, it seems challenging to verify the claim about the author's past questionable posts and clarifications. It may not be possible to confirm the accuracy of this claim without more specific details or references to the author's history.
# Answer: Unable to verify the claim regarding the author's past hasty posts and clarifications.
#
#
# Combining results...
#
# Final conclusion:
# Based on the verification results of the sub-questions provided, there is no specific information or evidence presented to suggest that Senator Schumer is immune to the kind of sexual accusations that many congressmen in Washington have faced. Additionally, there is no evidence to support the claim that the author of the article has made hasty posts in the past that might have been questionable, but clarifies they were not made out of ill will.
#
# Regarding the content of the original article, the author presents two questions without providing any verifiable facts or evidence to support the assertions made within these questions. These questions lack context, evidence, and substantiation, which could mislead readers into forming opinions without a factual basis.
#
# Therefore, considering the lack of specific claims or evidence provided in the original article and the inconclusive results of the verification of the sub-questions, the overall content of the article can be deemed as potentially misleading due to the lack of substantiated information.
#
# Final Answer: 1 (misleading)
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   current_df.at[idx, 'fact_check_response'] = cleaned_output
# Processing articles: 100%|██████████| 100/100 [46:45<00:00, 28.05s/it]
# All articles processed. Results saved to react_child_task_LLMFake_politifact-100.csv

# %% [markdown]
# ### analysis single article

# %%
checker = FactChecker()
article = """Taylor Swift: Why She Didn’t Have A Fourth Of July Party Again & Is ‘Happier’ Because Of It Taylor Swift opted to skip her Fourth of July bash for the second year in a row to go snorkeling with boyfriend Joe Alwyn. Here’s why she’s ‘happier’ with a more low-key celebration.

Taylor Swift, 28, has thrown some pretty epic Fourth of July parties in years past, but she’s forwent the epic celebration in 2017, and now again in 2018. This year, she instead spent her time off from touring to go to Turks and Caicos with boyfriend Joe Alwyn, 27.

“Taylor likes keeping things a little more low key nowadays because it works for her to have alone time and she is enjoying the time she needs and has with Joe,” a source close to the singer tells HollywoodLife EXCLUSIVELY. “It is very important for her for that to be private.”

The 10-time Grammy winner has been keeping her relationship under wraps. The pair have only been photographed out together a handful of times despite dating for well over a year. Taylor also rescinded from the spotlight in 2016, and has been living more privately ever since. Our insider adds that the “Delicate” hitmaker intends on keeping her life this way. “She is not interested in all the craziness from previous years. She has matured to this way of life and it fits and suits her so well,” our source explains. “She is happy and healthy and she’ll definitely continue this moving forward.”

Taymerica might be a thing of the past, but fans were still delighted when paparazzi photos of their idol surfaced online on July 5. The images showed Taylor swimming and snorkeling in the ocean with Joe, and they looked incredibly happy together. The “Shake It Off” songstress also paid tribute to her favorite holiday by rocking a red and white striped high-waisted bikini. Don’t worry Swifties, the Old Taylor is still alive and well."""
result = checker.verify_article(article)
# Out:
# Extracting sub-questions...
# Sub-questions extracted:
# 1. Why did Taylor Swift opt to skip her Fourth of July party for the second year in a row and go snorkeling with boyfriend Joe Alwyn instead?
# 2. Is it true that Taylor Swift is preferring a more low-key lifestyle nowadays and values privacy in her relationship with Joe Alwyn?
# 3. Is Taylor Swift intentionally stepping back from the spotlight and aiming to maintain a more private and mature way of life moving forward?
#
# Verifying: 1. Why did Taylor Swift opt to skip her Fourth of July party for the second year in a row and go snorkeling with boyfriend Joe Alwyn instead?
# Thought: This claim involves Taylor Swift opting to skip her Fourth of July party for the second year in a row to go snorkeling with her boyfriend Joe Alwyn instead. To verify this claim, I will search for information on Taylor Swift's recent activities and statements to see if she indeed chose a more low-key celebration this year.
#
# Action: call_google: Taylor Swift Fourth of July 2018 plans
#
#  -- running call_google Taylor Swift Fourth of July 2018 plans
#
# Observation: ["... Planning, Wedding Studio / By upframe. Taylor Swift's lyrics say, “You are in love, true love,” and we are too with this fourth of July weekend wedding! From\xa0...", 'Aug 4, 2022 ... August tends to be a bleak month — the Fourth of July fireworks are long in ... And yet, when Taylor croons the line cancel my plans just\xa0...', 'Dec 28, 2023 ... ... 2018, breaking a two-year hiatus from sharing her famous Fourth of July celebrations on social media. In 2020, Swift bid farewell to the\xa0...', "Jan 14, 2024 ... And her 'Swifties' wield huge power on social media.” ——-. Someone working so close with Kelce for so long to plan his post-football rise to\xa0...", 'Nov 19, 2018 ... 1M likes, 0 comments - taylorswift on November 19, 2018: "My new home ".', "Dec 9, 2023 ... Their source confirms that Taylor plans to release her next album by the end of the year. ... [July 13, 2017: Taylor's final social media\xa0...", 'Aug 16, 2024 ... I had no idea what I wanted to spend the next four years of my life focusing on. But the simple, meager plan I did make my first year of college\xa0...', "Jun 29, 2018 ... In People's new report today, its source also mentioned that Swift “has a few days off for July 4th” but gave no indication whether she'd\xa0...", "Q: What are your triathlon goals for this season? A: Well 2017 just finished this past Sunday with ironman Coeur d'Alene for me. I haven't started planning 2018\xa0...", "Aug 11, 2018 ... For years — nay, decades — my contributions to the Hingston clan's Memorial Day and Fourth of July ... plans to take over the world."]
#
# Thought: The search results did not provide specific information confirming Taylor Swift's plans for the Fourth of July in 2018. It seems like there is some discussion about past Fourth of July celebrations and lyrics related to the holiday, but not a direct confirmation of her skipping the party in 2018 for snorkeling with Joe Alwyn. I will need to refine the search query to find more relevant information.
#
# Action: call_google: Taylor Swift Fourth of July 2018 plans snorkeling
#
#  -- running call_google Taylor Swift Fourth of July 2018 plans snorkeling
#
# Observation: ["Apr 19, 2024 ... I'm not about to listen to @taylorswift new album, The Tortured Poets Department, for the next 48 hours straight & feel all of my feelings.", "Jan 14, 2024 ... And her 'Swifties' wield huge power on social media.” ——-. Someone working so close with Kelce for so long to plan his post-football rise to\xa0...", "Jul 31, 2020 ... Hey y'all! For those who don't know, I'm a huge Taylor Swift fan! I have loved her music (and her) since I was in 4th or 5th grade and have\xa0...", 'Jul 4, 2023 ... I love how I have had the first access to cultural products like movies and concerts (Taylor Swift concert changed my life). I love\xa0...', 'Aug 16, 2024 ... Performanceartlor is the theory that right at this moment Taylor Swift is engaged in a large-scale piece of performance art with her public image.', 'Jess and I began planning and design. We were deep diving through social media, watching music videos, listening to albums on loop, and studying live shows for\xa0...', 'July 13, 2018 - Taylor visits home and posts to IG with the lyric from style ... Be Here”- Toronto, Canada August 4th (august 4th 2014 Taylor wears one of the\xa0...', 'If you view it as more stressful and need guidance or ideas, check out my essential tips to help you plan a stress-free and fun birthday celebration.', 'Jun 29, 2018 ... I was pleased to see the Taylor Swift exhibit at the Country Music Hall of Fame! ... Sandra says 07 July 2018 at 09:46. Thanks for the article.', 'However, the booking of our Hawaii trip was a bit last minute because we had to cancel our Puerto Rico plans. That meant that almost all the Big Island hotels\xa0...']
#
# Thought: The search results are still not providing direct information about Taylor Swift's plans for the Fourth of July in 2018. The mentions of Taylor Swift are more related to her music and fan interactions. I will refine the search query once again to find specific details related to Taylor Swift skipping her Fourth of July party in 2018.
#
# Action: call_google: Taylor Swift Fourth of July 2018 plans snorkeling Joe Alwyn
#
#  -- running call_google Taylor Swift Fourth of July 2018 plans snorkeling Joe Alwyn
#
# Observation: ['Jan 31, 2024 ... July 2018: Joe and his family are seen at the Reputation tour. At ... Pic that got cut: December 2018 Taylor, Joe go to dinner with Abigail and\xa0...', 'Jun 19, 2024 ... 27, 2017: Ed Sheeran spills the beans on Alwyn. Dec. 11, 2017: The couple is spotted snuggling during an Ed Sheeran performance. May 8, 2018:\xa0...', 'Jan 14, 2024 ... ... July 2023. Pfizer ... Taylor had this kinda odd relationship for many years with an unknown Joe Alwyn that I actually do think was PR.', 'Jul 6, 2018 ... July 6, 2018. Image may contain Human Person Clothing Apparel Sunglasses Accessories Accessory Taylor Swift Female and Skin. NEW YORK, NY\xa0...', "Aug 10, 2018 ... I've read the news a little about the Famous scandal, Tom Hiddleston, Joe Alwyn, and Nicki Minaj. ... Taylor Swift Target Exclusive Magazine\xa0...", "Feb 9, 2024 ... July 2018: The couple takes a trip to Turks and Caicos. The pair skipped Taylor's annual 4th of July bash in favor of a tropical trip to\xa0...", '"Shake It Off" singer and her boyfriend celebrate the Fourth of July holiday in paradise. By Mike Vulpo Jul 06, 2018 6:55 AMTags. VacationTaylor\xa0...', 'Apr 9, 2023 ... Joe Alwyn got on really well with Taylor Swift, bruised and reputationally battered (through an illegally taped and deceptively edited phonecall)', 'Track by Track: reputation by Taylor Swift (for fans only). Everyone interacts with the media they consume in a different way. This is my interpretation of what\xa0...', 'Aug 24, 2019 ... Now 29, she has spent much of the past three years living quietly in London with her boyfriend, actor Joe Alwyn ... 2018 senate race. Vote\xa0...']
#
# Thought: The search results now provide more relevant information confirming that Taylor Swift did indeed skip her annual Fourth of July bash in 2018 in favor of a trip to Turks and Caicos with Joe Alwyn. The couple celebrated the Fourth of July holiday in paradise. This aligns with the claim that Taylor Swift opted for a more low-key celebration that year.
#
# Answer: Taylor Swift did opt to skip her Fourth of July party for the second year in a row in 2018 to go snorkeling in Turks and Caicos with her boyfriend Joe Alwyn. This information is confirmed by various sources mentioning their tropical trip instead of the traditional Fourth of July celebration.
#
#
# Verifying: 2. Is it true that Taylor Swift is preferring a more low-key lifestyle nowadays and values privacy in her relationship with Joe Alwyn?
# Thought: Taylor Swift's desire for a more low-key lifestyle and privacy in her relationship with Joe Alwyn seems to be supported by the information provided in the article. To verify this claim further and confirm if this is an accurate depiction of her current preferences, I might need to look for more recent information about Taylor Swift's lifestyle choices.
#
# Action: call_google: Taylor Swift low-key lifestyle 2021
#
#  -- running call_google Taylor Swift low-key lifestyle 2021
#
# Observation: ["France 2021's profile picture. France 2021. Runway walk's profile picture ... What Taylor swift said… Photo by Beauty lifestyle Fashion on May 18, 2024\xa0...", 'Sep 1, 2023 ... She continually refers to the live concert as "the best experience of my life." She says Taylor Swift is a "lifestyle." ... low-key Juggalos that\xa0...', 'Aug 11, 2021 ... ... likes, 38 comments - sopo.snaps on August 11, 2021: "cammy & colty ⚡️ @aviatornation @lowkey ... @sephora haul for Taylor Swift #erastour Detroit\xa0...', 'Apr 24, 2024 ... Lorde is a low profile- releasing albums every 4 years, not being on ... taylor swift and lorde both make incredible music, but taylor swift got\xa0...', "Apr 10, 2023 ... But Swift was low-key and a regular at pubs including The Spaniard's Inn in Hampstead, also a favorite of Styles. Primrose Hill 11. Swift and\xa0...", 'Aug 10, 2021 ... ... life. A California native, Tiffany enjoys makeup, anything Disney-related, Taylor Swift, and helping the CF community through her YouTube\xa0...', 'Dec 23, 2014 ... Profile photo for Quora User. Quora User. Law Student, Taylor Swift Aficionado. · Updated 8y. Related. What is Taylor Swift like in real life?', 'Jan 1, 2021 ... ... life. Many New Yorkers have long commutes, making it a key lifestyle issue. As companies reconsider their expensive Big Apple offices, and a\xa0...', "Feb 8, 2024 ... While Taylor is well within her rights to decide that a low-key love life no longer serves her, Joe certainly isn't a villain for not\xa0...", "Apr 12, 2021 ... There are people supportive of your choices and don't care if you're a low-key or a strict minimalist. ... Your Sweet Tiny Guide to Taylor Swift's\xa0..."]
#
# Thought: The search results didn't provide specific and recent information about Taylor Swift's lifestyle in 2021. However, the previous information from the article does suggest that Taylor Swift has been opting for a more low-key lifestyle and values privacy in her relationship with Joe Alwyn.
#
# Action: None needed at this time.
#
# Answer: Based on the provided article and the lack of conflicting information from recent searches, it is likely true that Taylor Swift is choosing a more low-key lifestyle and values privacy in her relationship with Joe Alwyn.
#
#
# Verifying: 3. Is Taylor Swift intentionally stepping back from the spotlight and aiming to maintain a more private and mature way of life moving forward?
# Thought: I can search for current information on Taylor Swift's recent activities and public appearances to determine if she is indeed stepping back from the spotlight and aiming for a more private and mature way of life.
# Action: call_google: Taylor Swift recent news
#
#  -- running call_google Taylor Swift recent news
#
# Observation: ['284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', "Taylor Swift's posts. Pinned ... breaking the all time attendance record for the stadium all 3 nights. Can't\xa0...", 'Taylor Swift · News · Taylor Swift writes letter to Dave Portnoy thanking him for support · Business · Vinyl to return to WH Smith stores for first time for\xa0...', 'Get the latest news updates on Taylor Swift - American singer-songwriter - from Mail Online.', 'Get the latest and most updated news, videos, and photo galleries about Taylor Swift.', 'Apr 20, 2024 ... I was listening to BBC World service and fucking every 5 minutes it felt like they were saying Taylor dropped a new album.', "Apr 19, 2024 ... Tuesday, November 26, 2024. Home; News · Michigan · MSU · Business · Environment · All News ... Swift's recent, sometimes oversaturated releases.", "Jun 30, 2019 ... Some fun facts about today's news: I learned about Scooter Braun's purchase of my masters as it was announced to the world. All I could\xa0...", 'Follow the latest Taylor Swift news stories and headlines. Get breaking news alerts when you download the ABC News App and subscribe to Taylor Swift\xa0...', 'Aileen Cannon tells woman suing Taylor Swift: Convince me not to end case. A woman suing Taylor Swift in Florida, alleging copyright infringement, is asking for\xa0...']
#
# Thought: The search results do not provide recent information specifically about Taylor Swift stepping back from the spotlight. I should focus on finding recent news articles or interviews that address her recent public presence and lifestyle choices.
# Action: call_google: Taylor Swift recent public appearances
#
#  -- running call_google Taylor Swift recent public appearances
#
# Observation: ['Dec 9, 2023 ... Sept 7, 2017: Taylor announces a new ... public appearance. Taylor winning a lawsuit for being sexually assaulted is not a public appearance.', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Oct 9, 2024 ... A whole new world of rock and roll opened up to me. Even though I immersed myself in rock music for the next 10 years, it took me a while to\xa0...', "Oct 18, 2024 ... The Eras Tour is BACK and the 3 Miami crowds we just got to play for were on a new level. With only 5 cities left to play before it's over, I\xa0...", 'Your online resource for everything Taylor Swift ; Last updated albums - Appearances ; 355.jpg 2024 MTV Video Music AwardsOct 13, 2024. 295.jpg 66th GRAMMY Awards\xa0...', 'Feb 5, 2024 ... Cline Dion made a surprise appearance at the Grammys on Sunday night\u200b, presenting Taylor Swift with the award for album of the year.', "Sep 10, 2024 ... The couple's latest public appearances gave fans a glimpse into how Swift and Kelce are approaching style these days, which has evolved from\xa0...", "Oct 25, 2024 ... Taylor Swift and Matty Healy's First Public Appearance Together. My husband woke me up to show me the breaking news – TAYLOR SWIFT ON THE\xa0...", 'Mar 5, 2024 ... ... recent escalation of the Palestinian crisis has led to many questioning their endorsements of public figures, I wonder if it will be enough\xa0...', 'Jun 19, 2024 ... June 15, 2024: Joe Alwyn finally shares his own words, explaining breakup with Swift from his POV. \ufeffJune 16: Alwyn makes first public appearance\xa0...']
#
# Thought: The search results show some recent public appearances made by Taylor Swift, contradicting the claim that she is intentionally stepping back from the spotlight. I should look for more recent sources that discuss her approach to privacy and her personal life to verify if she is aiming for a more private lifestyle.
# Action: call_google: Taylor Swift current approach to privacy and lifestyle
#
#  -- running call_google Taylor Swift current approach to privacy and lifestyle
#
# Observation: ['Apr 10, 2023 ... He said he was on board no matter what and she even completely conformed to the private lifestyle he wanted and it still ended this way. I\xa0...', 'Feb 13, 2024 ... Taylor Swift was criticised for private plane usage, with ... lifestyle – was originally exposed by Jack Sweeney, a student who tracks\xa0...', 'Jan 14, 2024 ... Lastly Taylor has been getting negative PR about her private jet use ... (current and former) who took their kids or partners to her\xa0...', 'Journalist. Media Executive. Currently: Group Publisher of lifestyle publications Eater, POPSUGAR, Punch, and Thrillist · Journalist and media executive who\xa0...', "Aug 3, 2023 ... A recent New York Times article reported, “A Taylor Swift concert in ... This means Swift's private jet footprint alone was 1,928 times the global\xa0...", "Oct 19, 2024 ... Taylor Swift and I Share the Same Core Values At this point in my personal and professional life, I'm making a conscious effort to say “yes”\xa0...", 'Apr 23, 2022 ... The Swift/Alwyn method of under-sharing still sparks intrigue about their relationship. ... Arts & LifestyleViewpoint. Vogue Recommends. 28\xa0...', 'Nov 14, 2024 ... Terms and Privacy Policy · Privacy ... Candid New Video of Taylor Swift Sneaking Out of Restaurant Confirms Recent Body Language Shift.', "Jan 28, 2018 ... I'm absolutely devastated over a recent fight with my best friend of more than a decade. She is white, and I am not.", 'Jun 13, 2023 ... The Midnights singer has been pretty private about her exercise routine in recent years, but Swift is a fan of dance-based cardio studio Body By\xa0...']
#
# Thought: The search results offer some information about Taylor Swift's private lifestyle and privacy concerns, but they do not provide a clear answer about whether she is intentionally stepping back from the spotlight. I need to narrow down the search to find more recent and specific sources addressing this claim directly.
# Action: call_google: Taylor Swift current approach to privacy and public presence
#
#  -- running call_google Taylor Swift current approach to privacy and public presence
#
# Observation: ['Sep 28, 2023 ... Ryan talking about her here and there during the recent Barbie promo was also very cute but revealed nothing about their private life. I just\xa0...', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Jan 14, 2024 ... And dating anyone and making it so public would go against this. The NFL has surely done her dirty with those mouth agape photos in every game,\xa0...', 'We work with industry, public and private institutions to explore the ongoing movements and pressures wrought by disruption. Emphasising the impact and promise\xa0...', 'When. Page 51. 45 explaining the production aspects of her music, Swift regularly used a comparative approach to explain what her current album sounds like when\xa0...', "Aug 17, 2023 ... By involving our fans, we create a sense of community and ownership in our projects. I've seen some recent troubled game companies largely\xa0...", 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', "May 30, 2023 ... It couldn't have been easy for her to relive this moment in the public ... Approach each day with the mindset of continuous improvement.", '... Taylor Swift to middle school students. Deepfakes inflict multifarious harms ... Meta Platforms, again employing a public health theory and taking\xa0...', 'She did it from the beginning-- connecting with her fan base on social media in the country era, which was unusual at the time. In a more recent move, she\xa0...']
#
# Thought: The search results are not providing specific information about Taylor Swift's current approach to privacy and her intention to step back from the spotlight. To verify this claim, I might need to focus on recent interviews or articles directly addressing her lifestyle choices.
# Action: call_google: Taylor Swift recent interviews on privacy and public presence
#
#  -- running call_google Taylor Swift recent interviews on privacy and public presence
#
# Observation: ['Jul 6, 2022 ... 187 votes, 63 comments. We all know that miss Swift is really popular and gets photographed whenever she goes out, however there are periods\xa0...', "... Taylor Swift's negative media presence is a result of misogynistic societal values and beliefs. ... Taylor recounts this feud in her 2023 interview with\xa0...", "Sep 28, 2023 ... This interview shows that this is the type of relationship Taylor always wanted and she didn't want a strictly private relationship.", '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', "Feb 1, 2024 ... Iron Maiden, Anthrax, and Ozzy are my favorites, so Swift isn't in my wheelhouse when it comes to music. In addition, I can't tell you the last\xa0...", 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', "May 30, 2023 ... Last Sunday evening, my twenty-three-year-old daughter chose to take me to see Taylor Swift's sold-out Eras Tour at Gillette Stadium in\xa0...", "Oct 16, 2024 ... The more interested the public is, the higher the currency of a celebrity's brand. taylor swift and travis kelce. Ezra Shaw//Getty Images. Fans\xa0...", "Seeing her performing it is an entirely different experience. Taylor Swift's new stage presence is an entirely difference experience. Perhaps it happened over\xa0...", 'These findings reinforce the themes found in the literature review and suggest new insights on celebrity, gender and sexism, artist autonomy, commodification,\xa0...']
#
# Thought: The search results provide a mix of information, including references to Taylor Swift's popularity, media presence, and interviews. There is a mention of an interview where Taylor expressed her desires for a specific type of relationship, but it does not directly address whether she is intentionally stepping back from the spotlight. I may need to search for more specific information about Taylor Swift's recent statements regarding her public presence and privacy.
# Action: call_google: Taylor Swift recent statements on privacy and stepping back from the spotlight
#
#  -- running call_google Taylor Swift recent statements on privacy and stepping back from the spotlight
#
# Observation: ["Dec 5, 2020 ... I don't blame Ariana for taking a step back from from her fans and the spotlight ... New comments cannot be posted and votes cannot be cast.", 'Mar 5, 2024 ... These are often the same celebrities that many of us have idolised growing up, and while the recent escalation of the Palestinian crisis has led\xa0...', "Jul 18, 2024 ... 388 votes, 91 comments. I wanna preface this by saying people should respect Chappell's boundaries, and I think she has absolutely every\xa0...", "Dec 23, 2014 ... As it happens, she was doing an interview on our country station's morning show, while I was doing morning news on mine. Our paths crossed in\xa0...", 'May 27, 2023 ... A more mature, but more wary Taylor who had learned to prioritise her private life over her fame, to dive deeper into her insecurities.', "Aug 3, 2018 ... ... step back from the media spotlight amid concerns over her father's latest statements about contact with the newlyweds. Prince Harry And\xa0...", "Jul 17, 2024 ... 2K votes, 192 comments. 119K subscribers in the chappellroan community. ✨ your favorite artist's favorite artist, the midwest princess\xa0...", 'LED 3 step dimmable Mio deals, HOFTRONIC Dimmable LED spotlight Bari white ... taylor swift pantyhose · spot lights led · pantyhose size chart · men wearing\xa0...', 'Feb 10, 2024 ... A racist ex! A pollutant-spewing private jet! White feminism! The sins of capitalism! Mutant cats! All her fault!', "Aug 21, 2024 ... Chappell Roan,Taylor Swift & The 'Stalker' Fans Ruining Music ... In July this year Chapell Roan said she was stepping back from the spotlight\xa0..."]
#
# Thought: The search results provide some references to celebrities taking a step back from the spotlight, including mentions of Taylor Swift prioritizing her private life over fame. There is also a mention of Chappell Roan stating she was stepping back from the spotlight. To verify if Taylor Swift is indeed aiming to maintain a more private and mature way of life moving forward, I may need to focus on recent statements from Taylor Swift herself or reputable sources discussing her approach to privacy.
# Action: call_google: Taylor Swift recent statements on privacy and public presence
#
#  -- running call_google Taylor Swift recent statements on privacy and public presence
#
# Observation: ['Jul 6, 2022 ... ... votes, 63 comments. We all know that miss Swift is really ... I bet celebrities have felt like they can own their privacy this way now.', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Dec 9, 2023 ... It is undeniable that she pulled back her public presence significantly. ... She was present in a few concerts or public/private events\xa0...', 'We work with industry, public and private institutions to explore the ongoing movements and pressures wrought by disruption. Emphasising the impact and promise\xa0...', 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', 'Oct 19, 2024 ... ... personal life, despite the public scrutiny and negativity. How Taylor Swift expresses her awareness and gratitude for her fame and\xa0...', 'Aug 11, 2023 ... Fans have been spending more than $1,300 on average on tickets, travel and new outfits for the concert night, according to Fortune. A survey\xa0...', 'These findings reinforce the themes found in the literature review and suggest new insights on celebrity, gender and sexism, artist autonomy, commodification,\xa0...', 'Debuting as a 16-year-old independent singer-songwriter in 2006, Swift steadily amassed fame, success, and public curiosity in her career, becoming a\xa0...', "6 days ago ... NFL Star Addresses Tech Moguls Controversial Comments · Travis Kelce's Profile · More videos on YouTube · Elon Musk's Public Presence · The\xa0..."]
#
# Thought: The search results provide some indications that Taylor Swift has pulled back her public presence significantly, as mentioned by sources. This aligns with the claim that she is aiming to maintain a more private and mature way of life. To confirm this, I should look for more recent and direct information about Taylor Swift's current stance on privacy and public presence.
# Action: call_google: Taylor Swift current stance on privacy and public presence
#
#  -- running call_google Taylor Swift current stance on privacy and public presence
#
# Observation: ['Jul 6, 2022 ... 187 votes, 63 comments. We all know that miss Swift is really popular and gets photographed whenever she goes out, however there are periods\xa0...', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Sep 28, 2023 ... Ryan talking about her here and there during the recent Barbie promo was also very cute but revealed nothing about their private life. I just\xa0...', 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', 'This (public) presentation of self is impacted by various factors: her celebrity status, position, and longevity in the American music industry, relationship\xa0...', 'The American singer-songwriter Taylor Swift is a topic of extensive mass media interest and press coverage. As a person both widely admired and scrutinized,\xa0...', 'May 30, 2023 ... Here are some of the many leadership lessons that can be learned by observing Swift. Take a stand. For years, Swift did what she was told.', "Oct 16, 2024 ... The more interested the public is, the higher the currency of a celebrity's brand. taylor swift and travis kelce. Ezra Shaw//Getty Images. Fans\xa0...", 'Feb 9, 2024 ... Some wonder if the current Super Bowl attendance reflects the ... Given that her presence in football is polarizing, some have claimed\xa0...', "Oct 19, 2024 ... Stephanie Glenn's Post. View profile for Stephanie Glenn, graphic. Stephanie Glenn. Technology Executive | Commercial Leader | SaaS Growth\xa0..."]
#
# Thought: The search results have provided various perspectives on Taylor Swift's public presence, her celebrity status, and how the public perceives her. While some references suggest she may have pulled back her public presence, there is not a definitive confirmation about her intentions to maintain a more private and mature way of life moving forward. To verify this claim, I may need to search for specific recent statements or interviews where Taylor Swift addresses her approach to privacy and public presence.
# Action: call_google: Taylor Swift recent statements on privacy and public presence
#
#  -- running call_google Taylor Swift recent statements on privacy and public presence
#
# Observation: ['Jul 6, 2022 ... ... votes, 63 comments. We all know that miss Swift is really ... I bet celebrities have felt like they can own their privacy this way now.', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Dec 9, 2023 ... It is undeniable that she pulled back her public presence significantly. ... She was present in a few concerts or public/private events\xa0...', 'We work with industry, public and private institutions to explore the ongoing movements and pressures wrought by disruption. Emphasising the impact and promise\xa0...', 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', 'Oct 19, 2024 ... ... personal life, despite the public scrutiny and negativity. How Taylor Swift expresses her awareness and gratitude for her fame and\xa0...', 'Aug 11, 2023 ... Fans have been spending more than $1,300 on average on tickets, travel and new outfits for the concert night, according to Fortune. A survey\xa0...', 'These findings reinforce the themes found in the literature review and suggest new insights on celebrity, gender and sexism, artist autonomy, commodification,\xa0...', 'Debuting as a 16-year-old independent singer-songwriter in 2006, Swift steadily amassed fame, success, and public curiosity in her career, becoming a\xa0...', "6 days ago ... NFL Star Addresses Tech Moguls Controversial Comments · Travis Kelce's Profile · More videos on YouTube · Elon Musk's Public Presence · The\xa0..."]
#
# Thought: The search results continue to indicate that Taylor Swift has pulled back her public presence significantly, supporting the claim that she is aiming to maintain a more private and mature way of life. While these references suggest a change in her approach to public life, to fully verify this claim, I should try to find more recent and direct statements from Taylor Swift or credible sources discussing her current stance on privacy and public presence.
# Action: call_google: Taylor Swift recent statements on privacy and public presence
#
#  -- running call_google Taylor Swift recent statements on privacy and public presence
#
# Observation: ['Jul 6, 2022 ... ... votes, 63 comments. We all know that miss Swift is really ... I bet celebrities have felt like they can own their privacy this way now.', '284M Followers, 0 Following, 675 Posts - Taylor Swift (@taylorswift) on Instagram: "All\'s fair in love and poetry... New album THE TORTURED POETS DEPARTMENT\xa0...', 'Dec 9, 2023 ... It is undeniable that she pulled back her public presence significantly. ... She was present in a few concerts or public/private events\xa0...', 'We work with industry, public and private institutions to explore the ongoing movements and pressures wrought by disruption. Emphasising the impact and promise\xa0...', 'Dec 23, 2014 ... Although Taylor may be able to determine who is writing this, I do not believe such information to be of use to the public. I am sure, if she\xa0...', 'Oct 19, 2024 ... ... personal life, despite the public scrutiny and negativity. How Taylor Swift expresses her awareness and gratitude for her fame and\xa0...', 'Aug 11, 2023 ... Fans have been spending more than $1,300 on average on tickets, travel and new outfits for the concert night, according to Fortune. A survey\xa0...', 'These findings reinforce the themes found in the literature review and suggest new insights on celebrity, gender and sexism, artist autonomy, commodification,\xa0...', 'Debuting as a 16-year-old independent singer-songwriter in 2006, Swift steadily amassed fame, success, and public curiosity in her career, becoming a\xa0...', "6 days ago ... NFL Star Addresses Tech Moguls Controversial Comments · Travis Kelce's Profile · More videos on YouTube · Elon Musk's Public Presence · The\xa0..."]
#
# Thought: The search results consistently suggest that Taylor Swift has indeed pulled back her public presence significantly. These references indicate a change in her approach to public life, with mentions of her being present at only a few select events. It seems likely that Taylor Swift is aiming to maintain a more private and mature way of life.
# Answer: Based on the information gathered that highlights Taylor Swift's reduced public presence and involvement in select events, it is plausible to conclude that she is indeed intentionally stepping back from the spotlight and aiming to maintain a more private and mature way of life moving forward.
#
#
# Combining results...
#
# Final conclusion:
# Based on the provided information, the article is based on statements from a source close to Taylor Swift and does not contain any verifiable claims that can be confirmed or refuted. The article discusses Taylor Swift's decision to skip her Fourth of July party for two years in a row, her preference for a low-key lifestyle, and her desire for privacy in her relationship with Joe Alwyn. These are subjective aspects related to Taylor Swift's personal life choices and preferences and cannot be fact-checked for accuracy.
#
# Therefore, the article does not contain any misleading information but rather presents information based on statements from a source close to Taylor Swift.
#
# Final Answer: 0

# %% [markdown]
# ### Caculate Accuracy

# %%
import pandas as pd

file_name = "react_child_task_LLMFake_politifact-100"

data = pd.read_csv(f'{file_name}.csv')
data['Simplified Answer'] = data['Simplified Answer'].astype(str)

# 計算總體準確率（僅考慮 0 和 1）
valid_predictions = data[data['Simplified Answer'].isin(['0', '1'])]
overall_accuracy = (valid_predictions['label'] == valid_predictions['Simplified Answer'].astype(int)).mean()

# 計算 label=1（假新聞）的準確率
label_1_data = valid_predictions[valid_predictions['label'] == 1]
accuracy_label_1 = (label_1_data['label'] == label_1_data['Simplified Answer'].astype(int)).mean()
mistakes_label_1 = len(label_1_data) - (label_1_data['label'] == label_1_data['Simplified Answer'].astype(int)).sum()

# 計算 label=0（真新聞）的準確率
label_0_data = valid_predictions[valid_predictions['label'] == 0]
accuracy_label_0 = (label_0_data['label'] == label_0_data['Simplified Answer'].astype(int)).mean()
mistakes_label_0 = len(label_0_data) - (label_0_data['label'] == label_0_data['Simplified Answer'].astype(int)).sum()

# 統計 "Uncertain" 和 "error" 的情況
uncertain_count = len(data[data['Simplified Answer'] == 'Unknown'])
error_count = len(data[data['Simplified Answer'] == 'ERROR'])

print(f"檔案名稱: {file_name}.csv")
print(f"總體準確率: {overall_accuracy:.2f}")
print(f"label=1（假新聞）的準確率: {accuracy_label_1:.2f}, 錯誤數量: {mistakes_label_1}")
print(f"label=0（真新聞）的準確率: {accuracy_label_0:.2f}, 錯誤數量: {mistakes_label_0}")
print(f"Uncertain 的數量: {uncertain_count}")
print(f"ERROR 的數量: {error_count}")
